# %% [markdown]
# # Milestone 3: Deployment and Real-Time Testing
#
# **Objective:** Deploy the facial recognition system and test it under real-world conditions.
#
# ## Outline
# 1. Launch the Flask application
# 2. Test `/health`, `/identify`, and `/verify` endpoints
# 3. Real-time webcam demo
# 4. Performance under challenging conditions

# %%
import sys
sys.path.insert(0, '..')

import requests
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Start the Flask Application
#
# Run the following command in a separate terminal before executing the cells below:
#
# ```bash
# python ../src/deployment/app.py
# ```

# %%
BASE_URL = 'http://127.0.0.1:5000'

resp = requests.get(f'{BASE_URL}/health')
print('Health check:', resp.json())

# %% [markdown]
# ## 2. Test /identify Endpoint

# %%
# Replace with a real image path
# image_path = '../data/raw/<identity>/.jpg'
# with open(image_path, 'rb') as f:
#     resp = requests.post(f'{BASE_URL}/identify', files={'image': f})
#     print(resp.json())

# %% [markdown]
# ## 3. Test /verify Endpoint

# %%
# Replace with real image paths
# with open('image1.jpg', 'rb') as f1, open('image2.jpg', 'rb') as f2:
#     resp = requests.post(f'{BASE_URL}/verify', files={'image1': f1, 'image2': f2})
#     print(resp.json())

# %% [markdown]
# ## 4. Real-Time Webcam Demo

# %%
# Uncomment and run in a standalone Python script (not Jupyter) for real-time inference
#
# cap = cv2.VideoCapture(0)
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#     _, buf = cv2.imencode('.jpg', frame)
#     resp = requests.post(f'{BASE_URL}/identify', files={'image': buf.tobytes()})
#     data = resp.json()
#     label = data.get('identity', 'unknown')
#     cv2.putText(frame, label, (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
#     cv2.imshow('Facial Recognition', frame)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()
